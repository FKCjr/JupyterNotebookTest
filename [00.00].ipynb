# %% [markdown]
# Import Packages

# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#mport seaborn as sns
#sns.set()

# %% [markdown]
# Import the Data

# %%
raw_csv_data = pd.read_csv('Index2018.csv')
raw_csv_data
# Out:
#             date          spx       dax         ftse    nikkei
# 0     07/01/1994   469.900000   2224.95  3445.980000  18124.01
# 1     10/01/1994   475.270000   2225.00  3440.580000  18443.44
# 2     11/01/1994   474.130000   2228.10  3413.770000  18485.25
# 3     12/01/1994   474.170000   2182.06  3372.020000  18793.88
# 4     13/01/1994   472.470000   2142.37  3360.010000  18577.26
# ...          ...          ...       ...          ...       ...
# 6264  23/01/2018  2839.130362  13559.60  7731.827774  24124.15
# 6265  24/01/2018  2837.544008  13414.74  7643.428966  23940.78
# 6266  25/01/2018  2839.253031  13298.36  7615.839954  23669.49
# 6267  26/01/2018  2872.867839  13340.17  7665.541292  23631.88
# 6268  29/01/2018  2853.528411  13324.48  7671.533300  23629.34
#
# [6269 rows x 5 columns]

# %%
df_comp = raw_csv_data.copy()

# %% [markdown]
# Examining the Data

# %%
df_comp.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df_comp.describe() # We will only obtain four columns because date is not numeric. The system omits such variables.
# count: shows the number of data entries in a column. 
# mean:average
# std :
# 25%:
# 50%:
# 75%:
# max:
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
df_comp.isna()
# Out:
#        date    spx    dax   ftse  nikkei
# 0     False  False  False  False   False
# 1     False  False  False  False   False
# 2     False  False  False  False   False
# 3     False  False  False  False   False
# 4     False  False  False  False   False
# ...     ...    ...    ...    ...     ...
# 6264  False  False  False  False   False
# 6265  False  False  False  False   False
# 6266  False  False  False  False   False
# 6267  False  False  False  False   False
# 6268  False  False  False  False   False
#
# [6269 rows x 5 columns]

# %%
df_comp.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
df_comp.spx.isna().sum()
# Out:
# 0

# %% [markdown]
# Plotting the Data

# %%
import matplotlib.pyplot as plt

# %%
df_comp.spx.plot(figsize = (20,5), title = 'S&P500 Prices') #notice the added code: figsize to stretch the plot
plt.show()

# %% [markdown]
# Notice that the x - axis is showing numbers only. However when dealing with proper time series, the x - axis has to show dates. Thisis because the index values are numeric rather than dates.

# %%
df_comp.ftse.plot(figsize = (20,5), title = 'S&P500 Prices') #notice the added code: figsize to stretch the plot
plt.show()

# %%
df_comp.spx.plot(figsize = (20,5), title = 'S&P500 Prices') #notice the added code: figsize to stretch the plot
#plt.show()
df_comp.ftse.plot(figsize = (20,5), title = 'S&P500 Prices') #notice the added code: figsize to stretch the plot
#plt.show()
plt.title('S&P v FTSE')
plt.show()

# %% [markdown]
# the s&p looks flat, which would seem intuitive to deduce that the data is more stable. However this is the reason why time series include compounded returns along with prices!

# %% [markdown]
# So far we have only plotted prices against time, but what if we want to plot the density of the data and which values are like to occur.

# %% [markdown]
# QQPlot : Quartile-Quantile Plot

# %%
import scipy.stats
import pylab

# %%
scipy.stats.probplot(df_comp.spx, plot = pylab)
pylab.show()

# %% [markdown]
# Theoretical quantiles : How many standard deviations away from the mean these values are.

# %% [markdown]
# The straight orange line represents what the data should follow if the varialbles are normally distrubted however we can see that there are more values concenctrated on the 500 mark. Therefore, we cannot use the elegant statistics of normal distributions as the data is not normal to make successful forecasts.

# %% [markdown]
# However this is what we expect from a time series
